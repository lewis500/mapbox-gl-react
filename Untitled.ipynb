# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from werkzeug.wrappers import Request, Response
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello():
    global a
    a+=1
    plt.plot(np.random.random(100))
    plt.show()
    print a
    return str(a)
#     return "Hello World!"

if __name__ == '__main__':
    from werkzeug.serving import run_simple
    run_simple('localhost', 9000, app)
# Out:
#  * Running on http://localhost:9000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/May/2018 22:47:15] "GET / HTTP/1.1" 200 -
# 30
# 127.0.0.1 - - [19/May/2018 22:48:04] "GET / HTTP/1.1" 200 -
# 31
# 127.0.0.1 - - [19/May/2018 22:48:09] "GET / HTTP/1.1" 200 -
# 32
# 127.0.0.1 - - [19/May/2018 22:48:10] "GET / HTTP/1.1" 200 -
# 33
# 127.0.0.1 - - [19/May/2018 22:48:11] "GET / HTTP/1.1" 200 -
# 34
# 127.0.0.1 - - [19/May/2018 22:48:11] "GET / HTTP/1.1" 200 -
# 35

# %%
a
# Out:
# 5

# %%
# app.stop()
print("hello")
# Out:
# hello
